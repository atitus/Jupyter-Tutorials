# %% [markdown]
# # Animating a Time-Dependent Function with Matplotlib

# %% [markdown]
# For classical waves or wave mechanics, you may want to animate a time-dependent function. The following resources may be helpful in using Matplotlib for animations.
#
# [Matplotlib Animation Tutorial (2012)](http://jakevdp.github.io/blog/2012/08/18/matplotlib-animation-tutorial/)
#
# [Animation Not Appearing in Jupyter](http://stackoverflow.com/questions/25333732/matplotlib-animation-not-working-in-ipython-notebook-blank-plot)

# %% [markdown]
# ## Setup
#
# Import packages and use a magic command to display the graph in the notebook.

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

# %%
#the "nbagg" parameter fixed a problem with the animation not displaying
# %matplotlib nbagg

# %% [markdown]
# ## Animation of a traveling wave.
#
# I copied this code from the Animation Tutorial referenced above. I used it to test animation in Jupyter.

# %%
# First set up the figure, the axis, and the plot element we want to animate
fig = plt.figure()
ax = plt.axes(xlim=(0, 2), ylim=(-2, 2))
line, = ax.plot([], [], lw=2)

# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
